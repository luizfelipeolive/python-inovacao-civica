# %% [markdown]
# # Limpeza de dados e estatística descritiva
#
# Neste desafio colocaremos em prática alguns conceitos apresentado nas aulas. Para isso, usaremos o conjunto de dados [Prestação de contas eleitorais - 2020](https://dadosabertos.tse.jus.br/dataset/prestacao-de-contas-eleitorais-2020) disponível no Portal de Dados Abertos do Tribunal Superior Eleitoral.
#
# Os dados também podem ser encontrados na pasta "Dados" deste repositório.
#
# Preencha as lacunas abaixo para completar o desafio.

# %% [markdown]
# # Importe os pacotes necessários

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %% [markdown]
# # Leia o arquivo "receitas_orgaos_partidarios_2020_NORTE.csv" que está na pasta dados desse repositório, usando o Pandas
#
# Na aula `1.10 - Outliers e valores faltantes`, vimos como utilizar o método `replace` para substituir valores em certos colunas do nosso dataframe e trocar o texto (string) `#NULO#` pela representação padrão do Pandas para valores nulos.
#
# Aqui, vamos utilizar um outro método, onde definimos quais strings serão considerados valores nulos já na importação do arquivo.
#
# Edite as células abaixo e inclua:
#
# * O nome do arquivo que queremos importar
# * O separador utilizado
# * Insira uma lista no parâmetro `na_values` que contenha o texto a ser ignorado.
#
# Experimente rodar os comandos primeiro sem e depois com o parâmetro `na_values`, então, compare a diferença. Observe, por exemplo, o campo `CD_CNAE_DOADOR`.

# %%
df = pd.read_csv('../base_dados/receitas_orgaos_partidarios_2020_NORTE.csv',sep=';')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6052 entries, 0 to 6051
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   DT_GERACAO                   6052 non-null   object
#  1   HH_GERACAO                   6052 non-null   object
#  2   ANO_ELEICAO                  6052 non-null   int64
#  3   CD_TIPO_ELEICAO              6052 non-null   int64
#  4   NM_TIPO_ELEICAO              6052 non-null   object
#  5   TP_PRESTACAO_CONTAS          6052 non-null   object
#  6   DT_PRESTACAO_CONTAS          6052 non-null   object
#  7   SQ_PRESTADOR_CONTAS          6052 non-null   int64
#  8   CD_ESFERA_PARTIDARIA         6052 non-null   object
#  9   DS_ESFERA_PARTIDARIA         6052 non-null   object
#  10  SG_UF                        6052 non-null   object
#  11  CD_MUNICIPIO                 5043 non-null   float64
#  12  NM_MUNICIPIO                 5043 non-null   object
#  13  NR_CNPJ_PRESTADOR_CONTA      6052 non-null   int64
#  14  NR_PARTIDO                   6052 non-null   int64
#  15  SG_PARTIDO                   6052 non-null   object
#  16  NM_PARTIDO                   6052 non-null   object
#  17  CD_FONTE_RECEITA             6052 non-null   int64
#  18  DS_FONTE_RECEITA             6052 non-null   object
#  19  CD_ORIGEM_RECEITA            6052 non-null   int64
#  20  DS_ORIGEM_RECEITA            6052 non-null   object
#  21  CD_NATUREZA_RECEITA          6052 non-null   int64
#  22  DS_NATUREZA_RECEITA          6052 non-null   object
#  23  CD_ESPECIE_RECEITA           6052 non-null   int64
#  24  DS_ESPECIE_RECEITA           6052 non-null   object
#  25  CD_CNAE_DOADOR               3033 non-null   float64
#  26  DS_CNAE_DOADOR               3033 non-null   object
#  27  NR_CPF_CNPJ_DOADOR           6016 non-null   float64
#  28  NM_DOADOR                    6016 non-null   object
#  29  NM_DOADOR_RFB                6016 non-null   object
#  30  CD_ESFERA_PARTIDARIA_DOADOR  2071 non-null   object
#  31  DS_ESFERA_PARTIDARIA_DOADOR  2071 non-null   object
#  32  SG_UF_DOADOR                 3033 non-null   object
#  33  CD_MUNICIPIO_DOADOR          1092 non-null   float64
#  34  NM_MUNICIPIO_DOADOR          1092 non-null   object
#  35  SQ_CANDIDATO_DOADOR          886 non-null    float64
#  36  NR_CANDIDATO_DOADOR          962 non-null    float64
#  37  CD_CARGO_CANDIDATO_DOADOR    962 non-null    float64
#  38  DS_CARGO_CANDIDATO_DOADOR    962 non-null    object
#  39  NR_PARTIDO_DOADOR            3033 non-null   float64
#  40  SG_PARTIDO_DOADOR            3033 non-null   object
#  41  NM_PARTIDO_DOADOR            3033 non-null   object
#  42  NR_RECIBO_DOACAO             5623 non-null   object
#  43  NR_DOCUMENTO_DOACAO          3924 non-null   object
#  44  SQ_RECEITA                   6052 non-null   int64
#  45  DT_RECEITA                   6052 non-null   object
#  46  DS_RECEITA                   1933 non-null   object
#  47  VR_RECEITA                   6052 non-null   object
# dtypes: float64(8), int64(10), object(30)
# memory usage: 2.2+ MB

# %%
df = pd.read_csv('../base_dados/receitas_orgaos_partidarios_2020_NORTE.csv',sep=';', na_values=['#NULO#'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6052 entries, 0 to 6051
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   DT_GERACAO                   6052 non-null   object
#  1   HH_GERACAO                   6052 non-null   object
#  2   ANO_ELEICAO                  6052 non-null   int64
#  3   CD_TIPO_ELEICAO              6052 non-null   int64
#  4   NM_TIPO_ELEICAO              6052 non-null   object
#  5   TP_PRESTACAO_CONTAS          6052 non-null   object
#  6   DT_PRESTACAO_CONTAS          6052 non-null   object
#  7   SQ_PRESTADOR_CONTAS          6052 non-null   int64
#  8   CD_ESFERA_PARTIDARIA         6052 non-null   object
#  9   DS_ESFERA_PARTIDARIA         6052 non-null   object
#  10  SG_UF                        6052 non-null   object
#  11  CD_MUNICIPIO                 5043 non-null   float64
#  12  NM_MUNICIPIO                 5043 non-null   object
#  13  NR_CNPJ_PRESTADOR_CONTA      6052 non-null   int64
#  14  NR_PARTIDO                   6052 non-null   int64
#  15  SG_PARTIDO                   6052 non-null   object
#  16  NM_PARTIDO                   6052 non-null   object
#  17  CD_FONTE_RECEITA             6052 non-null   int64
#  18  DS_FONTE_RECEITA             6052 non-null   object
#  19  CD_ORIGEM_RECEITA            6052 non-null   int64
#  20  DS_ORIGEM_RECEITA            6052 non-null   object
#  21  CD_NATUREZA_RECEITA          6052 non-null   int64
#  22  DS_NATUREZA_RECEITA          6052 non-null   object
#  23  CD_ESPECIE_RECEITA           6052 non-null   int64
#  24  DS_ESPECIE_RECEITA           6052 non-null   object
#  25  CD_CNAE_DOADOR               3033 non-null   float64
#  26  DS_CNAE_DOADOR               3033 non-null   object
#  27  NR_CPF_CNPJ_DOADOR           6016 non-null   float64
#  28  NM_DOADOR                    6016 non-null   object
#  29  NM_DOADOR_RFB                6016 non-null   object
#  30  CD_ESFERA_PARTIDARIA_DOADOR  2071 non-null   object
#  31  DS_ESFERA_PARTIDARIA_DOADOR  2071 non-null   object
#  32  SG_UF_DOADOR                 3033 non-null   object
#  33  CD_MUNICIPIO_DOADOR          1092 non-null   float64
#  34  NM_MUNICIPIO_DOADOR          1092 non-null   object
#  35  SQ_CANDIDATO_DOADOR          886 non-null    float64
#  36  NR_CANDIDATO_DOADOR          962 non-null    float64
#  37  CD_CARGO_CANDIDATO_DOADOR    962 non-null    float64
#  38  DS_CARGO_CANDIDATO_DOADOR    962 non-null    object
#  39  NR_PARTIDO_DOADOR            3033 non-null   float64
#  40  SG_PARTIDO_DOADOR            3033 non-null   object
#  41  NM_PARTIDO_DOADOR            3033 non-null   object
#  42  NR_RECIBO_DOACAO             5623 non-null   object
#  43  NR_DOCUMENTO_DOACAO          3924 non-null   object
#  44  SQ_RECEITA                   6052 non-null   int64
#  45  DT_RECEITA                   6052 non-null   object
#  46  DS_RECEITA                   1933 non-null   object
#  47  VR_RECEITA                   6052 non-null   object
# dtypes: float64(8), int64(10), object(30)
# memory usage: 2.2+ MB

# %% [markdown]
# # Filtre apenas os registros que sejam da prestação de contas final

# %%
# Primeiro vamos ver os valores únicos da coluna TP_PRESTACAO_CONTAS

df['TP_PRESTACAO_CONTAS'].unique()
# Out:
# array(['Final', 'Parcial', 'Relatório Financeiro',
#        'Regularização da Omissão'], dtype=object)

# %%
# O resultado deste comando nos diz que quantas linhas e colunas temos antes do filtro
df.shape
# Out:
# (6052, 48)

# %%
# Preencha o campo os espaços abaixo com o nome da coluna e o valor desejado para nosso filtro
df_final = df[df['TP_PRESTACAO_CONTAS'] == 'Final'].copy()

# %%
# Rode o comando shape no novo dataframe criado e confira se o número de linhas foi reduzido

df_final.shape
# Out:
# (5912, 48)

# %% [markdown]
# ## Qual foi a maior doação de pessoa física e pessoa jurídica em cada estado?
#
# Vamos usar o método `value_counts` para não só listar cada valor único da coluna `CD_CNAE_DOADOR`, como também mostrar quantos registros temos em cada um.

# %%
# Preencha o nome da coluna abaixo
df_final['CD_CNAE_DOADOR'].value_counts()
# Out:
# CD_CNAE_DOADOR
# 94928.0    2957
# 47814.0       2
# 59120.0       1
# 85996.0       1
# Name: count, dtype: int64

# %%
# Para ver os resultados em percentuais é fácil! Basta falarmos para o value_counts que queremos os resultados normalizados
df_final['CD_CNAE_DOADOR'].value_counts(normalize=True)
# Out:
# CD_CNAE_DOADOR
# 94928.0    0.998649
# 47814.0    0.000675
# 59120.0    0.000338
# 85996.0    0.000338
# Name: proportion, dtype: float64

# %%
df_final['DS_CNAE_DOADOR'].value_counts()
# Out:
# DS_CNAE_DOADOR
# Atividades de organizações políticas                                                 2957
# Comércio varejista de artigos do vestuário e acessórios                                 2
# Atividades de pós-produção cinematográfica, de vídeos e de programas de televisão       1
# Atividades de ensino não especificadas anteriormente                                    1
# Name: count, dtype: int64

# %% [markdown]
# Como faço para confirmar quais códigos correspondem as descrições da CNAE?

# %%
df_final['TIPO_DOADOR'] = df_final.loc[:, 'CD_CNAE_DOADOR'].replace(np.nan, -1)

# %%
df_final.sample(10)
# Out:
#       DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO NM_TIPO_ELEICAO  \
# 1570  13/05/2023   23:23:30         2020                2       Ordinária
# 2613  13/05/2023   23:23:30         2020                2       Ordinária
# 5640  13/05/2023   23:23:30         2020                2       Ordinária
# 5128  13/05/2023   23:23:30         2020                2       Ordinária
# 459   13/05/2023   23:23:30         2020                2       Ordinária
# 2252  13/05/2023   23:23:30         2020                2       Ordinária
# 173   13/05/2023   23:23:30         2020                2       Ordinária
# 4499  13/05/2023   23:23:30         2020                2       Ordinária
# 48    13/05/2023   23:23:30         2020                2       Ordinária
# 3852  13/05/2023   23:23:30         2020                2       Ordinária
#
#      TP_PRESTACAO_CONTAS DT_PRESTACAO_CONTAS  SQ_PRESTADOR_CONTAS  \
# 1570               Final          15/12/2020           1438431342
# 2613               Final          11/12/2020           1220374398
# 5640               Final          21/09/2021           1219991229
# 5128               Final          01/04/2021           1220312505
# 459                Final          15/12/2020           1220352794
# 2252               Final          18/04/2022           1293007003
# 173                Final          03/05/2022           1219892370
# 4499               Final          13/08/2021           1220375756
# 48                 Final          24/05/2021           2035356464
# 3852               Final          08/07/2021           1220374900
#
#      CD_ESFERA_PARTIDARIA          DS_ESFERA_PARTIDARIA  ...  \
# 1570                    M                     Municipal  ...
# 2613                    M                     Municipal  ...
# 5640                    M                     Municipal  ...
# 5128                    M                     Municipal  ...
# 459                     M                     Municipal  ...
# 2252                    M                     Municipal  ...
# 173                     F  Federal (Estadual/Distrital)  ...
# 4499                    M                     Municipal  ...
# 48                      F  Federal (Estadual/Distrital)  ...
# 3852                    M                     Municipal  ...
#
#      NR_PARTIDO_DOADOR  SG_PARTIDO_DOADOR  \
# 1570               NaN                NaN
# 2613               NaN                NaN
# 5640              25.0                DEM
# 5128              45.0               PSDB
# 459               25.0                DEM
# 2252               NaN                NaN
# 173               18.0               REDE
# 4499               NaN                NaN
# 48                12.0                PDT
# 3852               NaN                NaN
#
#                             NM_PARTIDO_DOADOR       NR_RECIBO_DOACAO  \
# 1570                                      NaN  P19000400310RO000018A
# 2613                                      NaN  P20000404120PA000007A
# 5640                               Democratas  P25000401554AC000004A
# 5128  Partido da Social Democracia Brasileira  P10000402658AM000003A
# 459                                Democratas  P25000496270TO000003A
# 2252                                      NaN  P13000404774PA000176A
# 173                     Rede Sustentabilidade  P18000306050AP000001A
# 4499                                      NaN  P45000404332PA000004A
# 48            Partido Democrático Trabalhista  P12000306050AP001804A
# 3852                                      NaN  P10000404200PA000002A
#
#       NR_DOCUMENTO_DOACAO SQ_RECEITA  DT_RECEITA  \
# 1570                  NaN   19198989  15/11/2020
# 2613                 9200   18007557  10/12/2020
# 5640               110904   20024984  09/11/2020
# 5128                  NaN   19829111  10/11/2020
# 459                 29780   19268121  15/12/2020
# 2252      603739000005214   20106985  15/12/2020
# 173       553596000023176   20108715  25/09/2020
# 4499            NSU595731   19966081  29/12/2020
# 48        551251000043402   19888158  18/11/2020
# 3852                 0131   19936024  08/12/2020
#
#                                DS_RECEITA VR_RECEITA  TIPO_DOADOR
# 1570  PRESTAÇÃO DE SERVIÇO FISCAL DE URNA     100.00         -1.0
# 2613                                  NaN       5.00         -1.0
# 5640                                  NaN    3250.00      94928.0
# 5128                  ASSESSORIA JURIDICA    1000.00      94928.0
# 459                                   NaN       4.95      94928.0
# 2252                                  NaN    5000.00         -1.0
# 173                                   NaN  460833.33      94928.0
# 4499                                  NaN    2000.00         -1.0
# 48                                    NaN  100000.00      94928.0
# 3852                                  NaN     927.30         -1.0
#
# [10 rows x 49 columns]

# %% [markdown]
# Se o doador for pessoa jurídica, temos seu respectivo código CNAE. Se for pessoa física, então temos o valor `-1`.
#
# Qual conclusão podemos tirar a respeito dos comandos acima?
#
# Escreva um **comentário** na célula abaixo com a resposta.

# %%
# Mais da metade dos registros são de pessoas físicas.

# %% [markdown]
# Agora, vamos duplicar a coluna `CD_CNAE_DOADOR` e deixar esta nova coluna apenas com 2 categorias: física (representada pelo valor -1) ou jurídica (que vamos representar inicialmente com 1).

# %%
# Vamos criar uma nova coluna que seja uma cópia exata da coluna CD_CNAE_DOADOR
#df_final['TIPO_DOADOR'] = df_final[_______]

# %% [markdown]
# ## Substituição condicional (conditional replacing)
#
# Agora, vamos usar o método where do pacote NumPy (carinhosamente chamado de np abaixo).
#
# Esta função recebe três parâmetros:
#
# * Uma condição: no nosso caso, queremos que filtrar as coluna do CNAE onde os valores sejam -1
# * Um valor: caso a condição acima seja verdadeira, qual valor deverá ser retornado?
# * Outro valor: se a condição for falsa, então, qual outro valor deverá ser retornado?

# %%
df_final['TIPO_DOADOR'] = np.where(df_final['TIPO_DOADOR'] == -1, 'fisica', 'juridica')

# %%
df_final.sample(15)
# Out:
#       DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO NM_TIPO_ELEICAO  \
# 1652  13/05/2023   23:23:30         2020                2       Ordinária
# 3065  13/05/2023   23:23:30         2020                2       Ordinária
# 1440  13/05/2023   23:23:30         2020                2       Ordinária
# 4402  13/05/2023   23:23:30         2020                2       Ordinária
# 2039  13/05/2023   23:23:30         2020                2       Ordinária
# 2615  13/05/2023   23:23:30         2020                2       Ordinária
# 63    13/05/2023   23:23:30         2020                2       Ordinária
# 3236  13/05/2023   23:23:30         2020                2       Ordinária
# 2137  13/05/2023   23:23:30         2020                2       Ordinária
# 1670  13/05/2023   23:23:30         2020                2       Ordinária
# 4986  13/05/2023   23:23:30         2020                2       Ordinária
# 3332  13/05/2023   23:23:30         2020                2       Ordinária
# 2944  13/05/2023   23:23:30         2020                2       Ordinária
# 1252  13/05/2023   23:23:30         2020                2       Ordinária
# 4901  13/05/2023   23:23:30         2020                2       Ordinária
#
#      TP_PRESTACAO_CONTAS DT_PRESTACAO_CONTAS  SQ_PRESTADOR_CONTAS  \
# 1652               Final          08/03/2021           1220302404
# 3065               Final          15/03/2021           1266355786
# 1440               Final          05/04/2021           1220300510
# 4402               Final          14/12/2020           1220373830
# 2039               Final          21/01/2021           1348106219
# 2615               Final          15/12/2020           1220374029
# 63                 Final          08/04/2021           1219900108
# 3236               Final          15/12/2020           1220376073
# 2137               Final          15/12/2020           1453001507
# 1670               Final          15/12/2020           1305219438
# 4986               Final          07/06/2021           1399833693
# 3332               Final          22/12/2020           1220376977
# 2944               Final          12/08/2021           1220378953
# 1252               Final          27/07/2021           1361981626
# 4901               Final          26/01/2022           1220312421
#
#      CD_ESFERA_PARTIDARIA          DS_ESFERA_PARTIDARIA  ...  \
# 1652                    M                     Municipal  ...
# 3065                    M                     Municipal  ...
# 1440                    F  Federal (Estadual/Distrital)  ...
# 4402                    M                     Municipal  ...
# 2039                    M                     Municipal  ...
# 2615                    M                     Municipal  ...
# 63                      M                     Municipal  ...
# 3236                    M                     Municipal  ...
# 2137                    M                     Municipal  ...
# 1670                    M                     Municipal  ...
# 4986                    M                     Municipal  ...
# 3332                    M                     Municipal  ...
# 2944                    M                     Municipal  ...
# 1252                    M                     Municipal  ...
# 4901                    M                     Municipal  ...
#
#      NR_PARTIDO_DOADOR  SG_PARTIDO_DOADOR  \
# 1652              15.0                MDB
# 3065               NaN                NaN
# 1440              13.0                 PT
# 4402               NaN                NaN
# 2039              55.0                PSD
# 2615               NaN                NaN
# 63                11.0                 PP
# 3236              45.0               PSDB
# 2137              23.0          CIDADANIA
# 1670               NaN                NaN
# 4986              36.0                PTC
# 3332               NaN                NaN
# 2944               NaN                NaN
# 1252               NaN                NaN
# 4901               NaN                NaN
#
#                             NM_PARTIDO_DOADOR       NR_RECIBO_DOACAO  \
# 1652         Movimento Democrático Brasileiro  P15000400396RO000005A
# 3065                                      NaN  P20000405690PA000010A
# 1440                Partido dos Trabalhadores  P13000300035RO000226A
# 4402                                      NaN  P45000404030PA000019A
# 2039               Partido Social Democrático  P55000404243PA000003A
# 2615                                      NaN  P11000404073PA000002A
# 63                              PROGRESSISTAS  P11000406076AP000001A
# 3236  Partido da Social Democracia Brasileira  P45000404383PA000008A
# 2137                                Cidadania  P23000405010PA000002A
# 1670                                      NaN  P25000400230RO000001A
# 4986              Partido Trabalhista Cristão                    NaN
# 3332                                      NaN  P15000404537PA000004A
# 2944                                      NaN  P20000404855PA000001A
# 1252                                      NaN  P25000400256RO000002A
# 4901                                      NaN  P55000402615AM000039A
#
#       NR_DOCUMENTO_DOACAO SQ_RECEITA  DT_RECEITA  \
# 1652      550102000091322   19787912  12/11/2020
# 3065               110601   19807529  06/11/2020
# 1440                 2020   19831239  30/09/2020
# 4402                  NaN   18546074  01/10/2020
# 2039               111101   19603971  11/11/2020
# 2615                  563   19386566  13/11/2020
# 63                 850010   19835753  22/10/2020
# 3236                  NaN   19098006  12/11/2020
# 2137       55091400034335   18937176  06/11/2020
# 1670                  NaN   19128530  13/11/2020
# 4986               850004   19900443  25/11/2020
# 3332            126901269   19510068  03/12/2020
# 2944                  NaN   19964103  26/10/2020
# 1252                  002   19951112  23/10/2020
# 4901                  NaN   20088817  15/11/2020
#
#                                  DS_RECEITA VR_RECEITA  TIPO_DOADOR
# 1652                                    NaN   20000.00     juridica
# 3065                                    NaN    2750.00       fisica
# 1440                                    NaN   81000.00     juridica
# 4402     DOAÇÃO DE SERVIÇOS ADMINISTRATIVOS    1700.00       fisica
# 2039                                    NaN   20000.00     juridica
# 2615                                    NaN    8500.00       fisica
# 63                                      NaN   54000.00     juridica
# 3236                     SERVI,OS CONTÁBEIS    1000.00     juridica
# 2137                                    NaN    3000.00     juridica
# 1670          HONORARIO PRESTAÇÃO DE CONTAS     600.00       fisica
# 4986                                    NaN       5.65     juridica
# 3332                                    NaN    2800.00       fisica
# 2944           SERV CONTABEIS ELEIÇOES 2020     500.00       fisica
# 1252                                    NaN    3500.00       fisica
# 4901  TERMO DE ADESÃO AO SERVIÇO VOLUNTÁRIO     100.00       fisica
#
# [15 rows x 49 columns]

# %%
df_final['TIPO_DOADOR'].unique()
# Out:
# array(['juridica', 'fisica'], dtype=object)

# %% [markdown]
# Obs: No fim das contas esse exemplo nem foi muito bom, porque nesses dados só estão relacionados doações de PJ. Não tem PF nessa base das receitas dos partidos na região Norte.

# %% [markdown]
# ## Agrupando (group by)

# %%
#Primeiro preciso substituir 'vírgula' por 'ponto' na varável 'VR_RECEITA'

df_final['VR_RECEITA'] = df_final['VR_RECEITA'].str.replace(',','.')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 3
#       1 #Primeiro preciso substituir 'vírgula' por 'ponto' na varável 'VR_RECEITA'
# ----> 3 df_final['VR_RECEITA'] = df_final['VR_RECEITA'].str.replace(',','.')
#
# File c:\Users\Luiz\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# File c:\Users\Luiz\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File c:\Users\Luiz\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\strings\accessor.py:181, in StringMethods.__init__(self, data)
#     178 def __init__(self, data) -> None:
#     179     from pandas.core.arrays.string_ import StringDtype
# --> 181     self._inferred_dtype = self._validate(data)
#     182     self._is_categorical = is_categorical_dtype(data.dtype)
#     183     self._is_string = isinstance(data.dtype, StringDtype)
#
# File c:\Users\Luiz\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\strings\accessor.py:235, in StringMethods._validate(data)
#     232 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     234 if inferred_dtype not in allowed_types:
# --> 235     raise AttributeError("Can only use .str accessor with string values!")
#     236 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
#convertendo os dados para FLOAT
df_final['VR_RECEITA'] = df_final['VR_RECEITA'].astype(float)

# %%
df_final['VR_RECEITA'].info
# Out:
# <bound method Series.info of 0         1000.0
# 1           36.0
# 2        15000.0
# 3       210000.0
# 4       482400.0
#           ...
# 6047       370.0
# 6048        37.0
# 6049       800.0
# 6050       265.0
# 6051       265.0
# Name: VR_RECEITA, Length: 5912, dtype: float64>

# %%
# no argumento final eu poderia substituir com a função que quisesse. Ex: mean(), max(), min()

df_final[['TIPO_DOADOR','SG_UF','VR_RECEITA']].groupby(by=['TIPO_DOADOR','SG_UF']).sum()
# Out:
#                     VR_RECEITA
# TIPO_DOADOR SG_UF
# fisica      AC       516688.26
#             AM       491585.92
#             AP        82687.88
#             PA      4532569.87
#             RO       815877.84
#             RR       170414.95
#             TO       414676.35
# juridica    AC     22585542.95
#             AM     35625509.00
#             AP     33073470.04
#             PA     42454506.85
#             RO     22978320.93
#             RR     20868194.74
#             TO     24682986.39

# %%
# Para repetir o valor da coluna TIPO_DOADOR nas linhas, coloque o parâmetro as_index=False no método groupby do comando acima

# %% [markdown]
# ## Qual o total de doações recebidas por partido?

# %%
total_doacoes = df_final[['SG_PARTIDO','VR_RECEITA']].groupby(by=['SG_PARTIDO']).sum()

print(total_doacoes)
# Out:
#                 VR_RECEITA
# SG_PARTIDO
# AVANTE           498726.86
# CIDADANIA       2219623.58
# DC               579762.02
# DEM             2436863.08
# MDB            26787221.17
# NOVO              23857.14
# PATRIOTA        2251979.23
# PC do B          828417.19
# PCB                5957.40
# PDT             4233608.09
# PL              1155281.57
# PMB              255200.00
# PMN                6161.18
# PODE           10923235.59
# PP             21131024.67
# PROS            3186342.45
# PRTB             149812.03
# PSB             7195707.60
# PSC              762219.20
# PSD            44622192.18
# PSDB            4703298.45
# PSL            14133814.44
# PSOL            7426889.30
# PT             11252216.64
# PTB             6212684.87
# PTC              621471.86
# PV              4670590.87
# REDE           10416744.67
# REPUBLICANOS    9731257.47
# SOLIDARIEDADE  10855671.17
# UP                15200.00

# %%
total_doacoes.tail()
# Out:
#                 VR_RECEITA
# SG_PARTIDO
# PV              4670590.87
# REDE           10416744.67
# REPUBLICANOS    9731257.47
# SOLIDARIEDADE  10855671.17
# UP                15200.00

# %% [markdown]
# ## Qual é o top 10?
#
# Crie um novo dataframe com os 10 partidos com mais doações. Você precisa primeiro ordenar os resultados e depois selecionar apenas os 10 primeiros.

# %%
total_doacoes_decrescente = total_doacoes.sort_values(by='VR_RECEITA',ascending=False).head(10)

print(total_doacoes_decrescente)
# Out:
#                 VR_RECEITA
# SG_PARTIDO
# PSD            44622192.18
# MDB            26787221.17
# PP             21131024.67
# PSL            14133814.44
# PT             11252216.64
# PODE           10923235.59
# SOLIDARIEDADE  10855671.17
# REDE           10416744.67
# REPUBLICANOS    9731257.47
# PSOL            7426889.30

# %% [markdown]
# # Vamos visualizar os resultados?
# Na aula, nós vimos como usar o matplotlib para gerar gráficos. Agora, vamos descobrir uma nova forma de fazer o mesmo usando um método nativo Pandas. Experimente colocar `.plot(kind='barh')` após a consulta ou dataframe anterior.
#
# Com este comando, podemos produzir um gráfico (plot) do tipo (kind) de barras horizontais (barh).

# %%
#df_final[__________].groupby(by=_____).___().sort_values(by='____',ascending=______).head(___).plot(kind='barh')

# %%
total_doacoes_decrescente.sort_values(by='VR_RECEITA').plot(kind='barh', color ={'red'})
# Out:
# <Axes: ylabel='SG_PARTIDO'>

# %% [markdown]
# ## Qual o valor médio das doações por tipo de doador?
#
# Agora é sua vez! A partir dos comandos anteriores, faça uma nova consulta para descobrir a mediana de acordo com o tipo de doador.

# %% [markdown]
# ## Qual o valor mais alto de doação por tipo de doador?

# %% [markdown]
# ## Crie uma tabela com valor máximo, mínimo e a mediana, por estado e tipo de doador

# %%
df_final[['TIPO_DOADOR','SG_UF','VR_RECEITA']].groupby(by=['TIPO_DOADOR','SG_UF']).agg({'VR_RECEITA': ['min','median','max']})
# Out:
#                   VR_RECEITA
#                          min    median        max
# TIPO_DOADOR SG_UF
# fisica      AC          4.80   3000.00    40560.0
#             AM          2.00    500.00    35000.0
#             AP         49.88    500.00    12000.0
#             PA          0.10   1000.00   200000.0
#             RO          1.20    600.00   110000.0
#             RR         23.74    300.00    30000.0
#             TO          0.01    561.65    30000.0
# juridica    AC         10.00   2550.00  4900000.0
#             AM          0.04   1500.00  6900000.0
#             AP          0.55  20000.00  4900000.0
#             PA          0.10    463.00  4400000.0
#             RO          0.40   7000.00  2900000.0
#             RR         12.50   2045.00  2900000.0
#             TO          0.05    600.00  4900000.0

# %% [markdown]
# # Entreviste você mesmo

# %% [markdown]
# Escreva abaixo pelo menos outras três perguntas que podem ser feitas à base de dados. Escreva a pergunta como um comentário acima do código com a consulta em Python.
