# %% [markdown]
# ## Leia o arquivo dos dados da Receita Federal e cruze eles com os dados da CEAP

# %% [markdown]
# ### CEAP

# %% [markdown]
# #### Baixando os dados da CEAP
#
# Todo aquele processo que já conhecemos :)

# %%
import requests

url = "http://www.camara.leg.br/cotas/Ano-2019.csv.zip"
r = requests.get(url)

# %%
file = open("Ano-2019.csv.zip", "wb")
file.write(r.content)
file.close()

# %%
from zipfile import ZipFile

zip_file = ZipFile("Ano-2019.csv.zip", 'r')

# %%
zip_file.extract(member="Ano-2019.csv", path="reembolso-2019")
# Out:
# 'reembolso-2019\\Ano-2019.csv'

# %%
zip_file.close()

# %% [markdown]
# #### Lendo os dados da CEAP

# %%
import pandas as pd

# usamos essa configuração para o pandas mostrar todas as colunas do dataframe.
pd.set_option('display.max_columns', None)

# %%
DTYPE = {
    'txNomeParlamentar': str,
    'ideCadastro': str,
    'nuCarteiraParlamentar': str,
    'nuLegislatura': str,
    'sgUF': str,
    'sgPartido': str,
    'codLegislatura': str,
    'numSubCota': str,
    'txtDescricao': str,
    'numEspecificacaoSubCota': str,
    'txtDescricaoEspecificacao': str,
    'txtFornecedor': str,
    'txtCNPJCPF': str,
    'txtNumero': str,
    'indTipoDocumento': str,
    'datEmissao': str,
    'vlrDocumento': float,
    'vlrGlosa': str,
    'vlrLiquido': float,
    'numMes': str,
    'numAno': str,
    'numParcela': str,
    'txtPassageiro': str,
    'txtTrecho': str,
    'numLote': str,
    'numRessarcimento': str,
    'nuDeputadoId': str,
    'ideDocumento': str,
}

df_reembolso = pd.read_csv("reembolso-2019/Ano-2019.csv", sep=";", dtype=DTYPE)

df_reembolso["datEmissao"] = df_reembolso["datEmissao"].astype('datetime64[ns]')

# %%
df_reembolso.head(1)
# Out:
#   txNomeParlamentar  cpf ideCadastro nuCarteiraParlamentar nuLegislatura sgUF  \
# 0        LID.GOV-CD  NaN         NaN                   NaN          2015  NaN
#
#   sgPartido codLegislatura numSubCota  \
# 0       NaN             55         13
#
#                                  txtDescricao numEspecificacaoSubCota  \
# 0  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       0
#
#   txtDescricaoEspecificacao           txtFornecedor          txtCNPJCPF  \
# 0                       NaN  CRISTIANE FERREIRA EPP  037.139.030/0010-8
#
#   txtNumero indTipoDocumento datEmissao  vlrDocumento vlrGlosa  vlrLiquido  \
# 0       693                4 2019-01-16         111.3        0       111.3
#
#   numMes numAno numParcela txtPassageiro txtTrecho  numLote numRessarcimento  \
# 0      1   2019          0           NaN       NaN  1554246              NaN
#
#   datPagamentoRestituicao  vlrRestituicao nuDeputadoId ideDocumento  \
# 0                     NaN             NaN         2812      6738121
#
#                                         urlDocumento
# 0  https://www.camara.leg.br/cota-parlamentar/not...

# %% [markdown]
# #### Tratando os dados da CEAP

# %% [markdown]
# ##### Padronizando colunas `txtCNPJCPF`

# %%
df_reembolso["txtCNPJCPF"]
# Out:
# 0         037.139.030/0010-8
# 1         037.139.030/0010-8
# 2         037.139.030/0010-8
# 3         037.139.030/0010-8
# 4         037.139.030/0010-8
#                  ...
# 289448    020.128.620/0016-0
# 289449     007.227.727/00  -
# 289450    020.128.620/0016-0
# 289451    000.000.000/0000-6
# 289452    096.026.750/0018-5
# Name: txtCNPJCPF, Length: 289453, dtype: object

# %%
df_reembolso["txtCNPJCPF"] = df_reembolso["txtCNPJCPF"].str.replace(r'\D', '', regex=True)

df_reembolso["txtCNPJCPF"]
# Out:
# 0         03713903000108
# 1         03713903000108
# 2         03713903000108
# 3         03713903000108
# 4         03713903000108
#                ...
# 289448    02012862000160
# 289449       00722772700
# 289450    02012862000160
# 289451    00000000000006
# 289452    09602675000185
# Name: txtCNPJCPF, Length: 289453, dtype: object

# %% [markdown]
# ##### Padronizando CPFs nulos

# %%
filtro_cpf_nulo = df_reembolso.cpf.isna()

filtro_cpf_nulo
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 289448    False
# 289449    False
# 289450    False
# 289451    False
# 289452    False
# Name: cpf, Length: 289453, dtype: bool

# %%
df_reembolso.loc[filtro_cpf_nulo, "cpf"] = "-1"

# %%
df_reembolso.cpf
# Out:
# 0                   -1
# 1                   -1
# 2                   -1
# 3                   -1
# 4                   -1
#               ...
# 289448    5461154387.0
# 289449    9300885731.0
# 289450    9300885731.0
# 289451    9300885731.0
# 289452    9300885731.0
# Name: cpf, Length: 289453, dtype: object

# %% [markdown]
# ##### Padronizando Partidos nulos

# %%
filtro_partido_null = df_reembolso.sgPartido.isna()

filtro_partido_null
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 289448    False
# 289449    False
# 289450    False
# 289451    False
# 289452    False
# Name: sgPartido, Length: 289453, dtype: bool

# %%
df_reembolso.loc[filtro_partido_null, "sgPartido"] = "-1"

# %%
df_reembolso.sgPartido
# Out:
# 0                   -1
# 1                   -1
# 2                   -1
# 3                   -1
# 4                   -1
#               ...
# 289448    REPUBLICANOS
# 289449              PL
# 289450              PL
# 289451              PL
# 289452              PL
# Name: sgPartido, Length: 289453, dtype: object

# %% [markdown]
# ##### Padronizando data de emissão

# %%
df_reembolso["datEmissao"]
# Out:
# 0        2019-01-16
# 1        2019-02-04
# 2        2019-02-25
# 3        2019-03-28
# 4        2019-05-07
#             ...
# 289448   2019-12-11
# 289449   2019-12-31
# 289450   2019-12-18
# 289451          NaT
# 289452   2020-01-31
# Name: datEmissao, Length: 289453, dtype: datetime64[ns]

# %%
df_reembolso["datEmissao"] = pd.to_datetime(df_reembolso["datEmissao"], format="%Y-%m-%d")

df_reembolso["datEmissao"]
# Out:
# 0        2019-01-16
# 1        2019-02-04
# 2        2019-02-25
# 3        2019-03-28
# 4        2019-05-07
#             ...
# 289448   2019-12-11
# 289449   2019-12-31
# 289450   2019-12-18
# 289451          NaT
# 289452   2020-01-31
# Name: datEmissao, Length: 289453, dtype: datetime64[ns]

# %% [markdown]
# ### Receita Federal

# %% [markdown]
# #### Baixando os dados da RF

# %%
import requests

url = "https://serenata-de-amor-data.nyc3.digitaloceanspaces.com/2019-11-19-companies.csv.xz"

# fazendo o download do conteúdo do arquivo
r = requests.get(url)

# abrindo um arquivo no seu computador
file = open('2019-11-19-companies.csv.xz', "wb")

# escrever o conteúdo
file.write(r.content)
file.close()

# %% [markdown]
# #### Lendo os dados da RF

# %%
! pip install lzma
# Out:
# ERROR: Could not find a version that satisfies the requirement lzma (from versions: none)
# ERROR: No matching distribution found for lzma

# %%
DTYPE = {
    'cnpj': str
}

df_empresas = pd.read_csv(
    '2019-11-19-companies.csv.xz',
    compression='xz',
    dtype=DTYPE,
)

# %% [markdown]
# ### Juntando os dados

# %%
# fizemos o merge da tabela df_reembolso com df_empresas.
# LEMBRANDO:
# df_reembolso é considerada a tabela da esquerda, então ela é a left.
# df_empresas é considerada a tabela da direita, então ela é a right.
df_final = df_reembolso.merge(
    df_empresas,
    how='left',
    left_on='txtCNPJCPF',
    right_on='cnpj'
)

# %%
df_final[['txtCNPJCPF', 'cnpj']]
# Out:
#             txtCNPJCPF            cnpj
# 0       03713903000108  03713903000108
# 1       03713903000108  03713903000108
# 2       03713903000108  03713903000108
# 3       03713903000108  03713903000108
# 4       03713903000108  03713903000108
# ...                ...             ...
# 479099     00722772700             NaN
# 479100  02012862000160  02012862000160
# 479101  02012862000160  02012862000160
# 479102  00000000000006             NaN
# 479103  09602675000185             NaN
#
# [479104 rows x 2 columns]

# %% [markdown]
# ## Some o total da coluna `vlrLiquido` agrupando por `txtCNPJCPF` e `txtFornecedor`

# %%
# aqui nós configuramos para o pandas mostrar números decimais considerando somente
# 2 casas decimais depois do ponto
pd.options.display.float_format = '{:,.2f}'.format

# %%
# agrupamos os dados por txtCNPJCPF e txtFornecedor.
# somamos o vlrLiquido considerando o grupo resultante pelo groupby
# nós pegamos tbm só os 10 primeiros itens através do [:10]
df_reembolso.groupby(
    ['txtCNPJCPF', 'txtFornecedor']
)['vlrLiquido'].sum().sort_values().to_frame()[:10]
# Out:
#                                                                    vlrLiquido
# txtCNPJCPF     txtFornecedor
# 30159008000166 PAPELARIA E BAZAR SANTA LUZIA                             2.20
# 73830069000116 J.V. COMÉRCIO DE PETRÓLEO LTDA.                           2.55
# 18572225000269 Concessionária das Rodovias Centrais do Brasil ...        3.30
# 04699200000135 W P PARK ESTACIONAMENTO LTDA ME                           3.60
# 02415408000150 CONCESSIONARIA DE RODOVIAS DO OESTE DE SAO PAUL...        3.80
# 25453685000152 BRUNA BANDEIRA FERRARI ME                                 4.00
# 61012704000179 PANIFICADORA MERCURIO EIRELI - EPP                        4.10
# 04506629000169 NOVA ALIANÇA ATACADO LTDA - EPP 2                         4.59
# 28019100000189 VIAPAULISTA S.A.                                          4.60
# 37065604000398 BRASILIA PARTIC PLANEJ E ADMIN DE SHOPPING CENT...        4.70

# %% [markdown]
# ### Ordene os dados da consulta anterior de forma decrescente

# %%
df_reembolso.groupby(['txtCNPJCPF', 'txtFornecedor'])['vlrLiquido'].sum().sort_values(
    ascending=False
).to_frame()[:10]
# Out:
#                                                                  vlrLiquido
# txtCNPJCPF     txtFornecedor
# 02012862000160 Cia Aérea - TAM                                24,922,866.52
# 07575651000159 Cia Aérea - GOL                                22,007,041.30
# 09296295000160 Cia Aérea - AZUL                                6,440,767.66
# 07319323000191 PANTANAL VEÍCULOS LTDA                          2,181,274.52
# 02012862000160 TAM LINHAS AEREAS S/A.                          1,172,126.78
# 02575829000148 Cia Aérea - AVIANCA                             1,137,800.63
# 23721017000133 T2 COMUNICACAO, VIDEO E PRODUCOES EIRELI - EPP  1,097,334.00
# 00000000000001 CELULAR FUNCIONAL                                 872,853.43
# 02558157000162 TELEFÔNICA BRASIL S.A. VIVO                       860,813.15
# 02610235000120 DMD Gestão Administrativa LTDA - ME               805,000.00

# %%
# pegando dados do final de semana
df_reembolso["datEmissao"].dt.dayofweek < 5
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 289448     True
# 289449     True
# 289450     True
# 289451    False
# 289452     True
# Name: datEmissao, Length: 289453, dtype: bool

# %%
# usando a opção de normalizar o resultado do value_counts
# também ordenamos por ordem decrescente
df_reembolso.txtDescricao.value_counts(normalize=True).sort_values(ascending=False).to_frame().head(10)
# Out:
#                                                     proportion
# txtDescricao
# PASSAGEM AÉREA - RPA                                      0.28
# COMBUSTÍVEIS E LUBRIFICANTES.                             0.22
# SERVIÇO DE TÁXI, PEDÁGIO E ESTACIONAMENTO                 0.11
# MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE P...        0.08
# TELEFONIA                                                 0.08
# FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                0.06
# SERVIÇOS POSTAIS                                          0.05
# DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                      0.04
# LOCAÇÃO OU FRETAMENTO DE VEÍCULOS AUTOMOTORES             0.02
# HOSPEDAGEM ,EXCETO DO PARLAMENTAR NO DISTRITO F...        0.02

# %%
df_reembolso["vlrLiquido"].describe()
# Out:
# count   289,453.00
# mean        730.24
# std       2,083.63
# min      -6,605.57
# 25%          50.00
# 50%         191.84
# 75%         715.75
# max     145,140.00
# Name: vlrLiquido, dtype: float64

# %%
# usamos 2 filtros aqui, para txtDescricao e para vlrLiquido

filtro_cat_alim = df_reembolso.txtDescricao == 'FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR'
filtro_vlr_max = df_reembolso.vlrLiquido > 5000

df_reembolso[(filtro_cat_alim) & (filtro_vlr_max)]
# Out:
#                                     txNomeParlamentar cpf ideCadastro  \
# 152  LIDERANÇA DO PARTIDO REPUBLICANO DA ORDEM SOCIAL  -1         NaN
# 159  LIDERANÇA DO PARTIDO REPUBLICANO DA ORDEM SOCIAL  -1         NaN
# 160  LIDERANÇA DO PARTIDO REPUBLICANO DA ORDEM SOCIAL  -1         NaN
# 164  LIDERANÇA DO PARTIDO REPUBLICANO DA ORDEM SOCIAL  -1         NaN
# 168  LIDERANÇA DO PARTIDO REPUBLICANO DA ORDEM SOCIAL  -1         NaN
# 264                        LIDERANÇA DO PROGRESSISTAS  -1         NaN
# 265                        LIDERANÇA DO PROGRESSISTAS  -1         NaN
# 266                        LIDERANÇA DO PROGRESSISTAS  -1         NaN
# 267                                  LIDERANÇA DO PSD  -1         NaN
# 283                                  LIDERANÇA DO PSD  -1         NaN
#
#     nuCarteiraParlamentar nuLegislatura sgUF sgPartido codLegislatura  \
# 152                   NaN          2019  NaN        -1             56
# 159                   NaN          2019  NaN        -1             56
# 160                   NaN          2019  NaN        -1             56
# 164                   NaN          2019  NaN        -1             56
# 168                   NaN          2019  NaN        -1             56
# 264                   NaN          2019  NaN        -1             56
# 265                   NaN          2019  NaN        -1             56
# 266                   NaN          2019  NaN        -1             56
# 267                   NaN          2015  NaN        -1             55
# 283                   NaN          2019  NaN        -1             56
#
#     numSubCota                                txtDescricao  \
# 152         13  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
# 159         13  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
# 160         13  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
# 164         13  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
# 168         13  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
# 264         13  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
# 265         13  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
# 266         13  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
# 267         13  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
# 283         13  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
#
#     numEspecificacaoSubCota txtDescricaoEspecificacao  \
# 152                       0                       NaN
# 159                       0                       NaN
# 160                       0                       NaN
# 164                       0                       NaN
# 168                       0                       NaN
# 264                       0                       NaN
# 265                       0                       NaN
# 266                       0                       NaN
# 267                       0                       NaN
# 283                       0                       NaN
#
#                                          txtFornecedor      txtCNPJCPF  \
# 152  ARTESANAL SERVICOS DE ALIMENTACAO E BUFFET EIRELI  22836210000157
# 159                           SILT SELF SERVICE EIRELI  07286731000194
# 160                        SILT SELF SERVICE EIRELI ME  07286731000194
# 164                        SILT SELF SERVICE EIRELI ME  07286731000194
# 168                        SILT SELF SERVICE EIRELI ME  07286731000194
# 264                 RONILDA FRANCISCA RIBEIRO DOS REIS  20869131000117
# 265                 RONILDA FRANCISCA RIBEIRO DOS REIS  20869131000117
# 266                 RONILDA FRANCISCA RIBEIRO DOS REIS  20869131000117
# 267                          ROBERTTH MOREIRA DE JESUS  30561574000108
# 283                RAFAEL DOS SANTOS SILVA 72238208100  22836210000157
#
#      txtNumero indTipoDocumento          datEmissao  vlrDocumento vlrGlosa  \
# 152          7                4 2019-12-11 00:00:00      6,000.00        0
# 159        636                4 2019-11-05 23:00:00      6,000.00        0
# 160        295                4 2019-04-03 00:00:00      6,000.00        0
# 164        394                4 2019-07-02 00:00:00      5,400.00        0
# 168        520                4 2019-09-25 00:00:00      6,000.00        0
# 264  001525287                0 2019-11-07 23:00:00      8,000.00        0
# 265  001546052                0 2019-11-24 23:00:00      8,000.00        0
# 266  001579281                0 2019-12-15 23:00:00      8,000.00        0
# 267  001186205                0 2019-01-31 00:00:00      5,355.00        0
# 283  001376062                0 2019-07-12 00:00:00      5,249.85        0
#
#      vlrLiquido numMes numAno numParcela txtPassageiro txtTrecho  numLote  \
# 152    6,000.00     11   2019          0           NaN       NaN  1661111
# 159    6,000.00     10   2019          0           NaN       NaN  1650383
# 160    6,000.00      4   2019          0           NaN       NaN  1581569
# 164    5,400.00      6   2019          0           NaN       NaN  1609922
# 168    6,000.00      9   2019          0           NaN       NaN  1636965
# 264    8,000.00     10   2019          0           NaN       NaN  1651228
# 265    8,000.00     11   2019          0           NaN       NaN  1655704
# 266    8,000.00     12   2019          0           NaN       NaN  1663508
# 267    5,355.00      1   2019          0           NaN       NaN  1558264
# 283    5,249.85      7   2019          0           NaN       NaN  1616327
#
#     numRessarcimento datPagamentoRestituicao  vlrRestituicao nuDeputadoId  \
# 152              NaN                     NaN             NaN         2865
# 159              NaN                     NaN             NaN         2865
# 160              NaN                     NaN             NaN         2865
# 164              NaN                     NaN             NaN         2865
# 168              NaN                     NaN             NaN         2865
# 264              NaN                     NaN             NaN         3461
# 265              NaN                     NaN             NaN         3461
# 266              NaN                     NaN             NaN         3461
# 267              NaN                     NaN             NaN         2725
# 283              NaN                     NaN             NaN         2725
#
#     ideDocumento                                       urlDocumento
# 152      6981848  https://www.camara.leg.br/cota-parlamentar/not...
# 159      6956990  https://www.camara.leg.br/cota-parlamentar/not...
# 160      6798895  https://www.camara.leg.br/cota-parlamentar/not...
# 164      6864494  https://www.camara.leg.br/cota-parlamentar/not...
# 168      6926450  https://www.camara.leg.br/cota-parlamentar/not...
# 264      6959055  https://www.camara.leg.br/cota-parlamentar/doc...
# 265      6969841  https://www.camara.leg.br/cota-parlamentar/doc...
# 266      6987099  https://www.camara.leg.br/cota-parlamentar/doc...
# 267      6747304  https://www.camara.leg.br/cota-parlamentar/doc...
# 283      6879754  https://www.camara.leg.br/cota-parlamentar/doc...

# %%
# aqui nós agrupamos por partido, UF e nome do parlamentar.
# Somamos o vlrLiquido considerando os grupos gerados pelo groupby
# ordenamos de forma decrescente

df_reembolso.groupby(
    ['sgPartido', 'sgUF', 'txNomeParlamentar']
)["vlrLiquido"].sum().sort_values(ascending=False).to_frame()
# Out:
#                                        vlrLiquido
# sgPartido sgUF txNomeParlamentar
# PP        RR   Hiran Gonçalves         542,487.76
# MDB       AC   Jéssica Sales           537,322.05
# PDT       RS   Afonso Motta            537,270.79
# PCdoB     AC   Perpétua Almeida        536,138.75
# MDB       AC   Flaviano Melo           520,071.45
# ...                                           ...
# PCdoB     PE   LUCIANA SANTOS                0.49
# PSL       MG   Marcelo Álvaro Antônio     -270.84
# PODE      PR   Luiz Carlos Hauly          -784.47
# UNIÃO     PE   Mendonça Filho             -804.72
# PROS      RJ   FELIPE BORNIER           -1,675.06
#
# [907 rows x 1 columns]

# %% [markdown]
# ### Consulte se houveram gastos reembolsados associados a empresas que na época estavam com status `08`
#
#
# status == 8 significa `BAIXADA` (*a empresa foi extinta, seja por solicitação dos sócios ou por ação da Receita*)

# %%
# situation == 8 significa empresa que está BAIXADA
f = df_final.situation == 8

df_final[f].shape
# Out:
# (293, 75)

# %%
# datEmissao é a coluna que informa a data em que o gasto foi feito (vem da base da CEAP)
# situation_date é a coluna que informa a data em que a empresa ficou com a situação da coluna situation (vem da Receita Federal)
df_final["datEmissao"] = pd.to_datetime(df_final["datEmissao"], format="%Y-%m-%d")
df_final['situation_date'] = pd.to_datetime(df_final["situation_date"], format="%Y-%m-%d")

# %% [markdown]
# Lembrando, se temos `datEmissao` como `02/10/2020` e `situation_date` como `01/10/2020`, o python/pandas vai entender que `datEmissao` contém uma data posterior a `situation_date`, logo, é uma _data maior_. Por isso podemos fazer algo como `datEmissao` > `situation_date`, isso vai ser verdadeiro se a `datEmissao` for uma data que veio depois de `situation_date`.

# %%
# aqui vamos pesquisar se a data do gasto veio depois da data em que a empresa mudou de situação
# vamos agrupar por txNomeParlamentar
# aplicamos count em ideDocumento e sum em vlrLiquido
# ordenamos o resultado por vlrLiquido
(
    df_final[f].query('datEmissao > situation_date')
    .groupby('txNomeParlamentar')
    .agg({'ideDocumento': 'count', 'vlrLiquido': 'sum'})
    .sort_values(by='vlrLiquido', ascending=False)
    .reset_index()
)
# Out:
#              txNomeParlamentar  ideDocumento  vlrLiquido
# 0              Gleisi Hoffmann            42   62,065.18
# 1                 Carlos Veras            10   11,396.40
# 2               Carla Zambelli             1    7,289.65
# 3               Darci de Matos             1    2,869.38
# 4           General Peternelli            22    2,805.31
# 5               Geovania de Sá             2    2,703.30
# 6               Lucas Redecker             8    2,308.40
# 7                  Enéias Reis             1    1,729.39
# 8                 Carlos Gomes             1    1,560.00
# 9                   José Nunes             1    1,510.40
# 10                Paulo Ganime             2    1,244.16
# 11           Haroldo Cathedral             1    1,195.85
# 12  Professora Dayane Pimentel             9    1,142.25
# 13    José Airton Félix Cirilo             4      702.78
# 14               Fábio Ramalho             1      500.00
# 15        Lafayette de Andrada             3      421.50
# 16              João H. Campos             1      353.82
# 17                 CELSO JACOB             1      280.00
# 18            Damião Feliciano             1      259.79
# 19              Luizianne Lins             2      117.80
# 20          Euclydes Pettersen             1      100.00
# 21          Toninho Wandscheer             1       80.00
# 22               Coronel Tadeu             1       77.70
# 23             Carlos Chiodini             2       62.80
# 24              André de Paula             1       47.94
# 25           Alexandre Padilha             3       45.38
# 26               Túlio Gadêlha             1       42.00
# 27             Capitão Augusto             6       39.00
# 28         Coronel Chrisóstomo             1       30.35
# 29             Daniel Silveira             1       26.06
# 30         Sóstenes Cavalcante             1       26.00
# 31                 Jorge Solla             1       22.00
# 32          Hermes Parcianello             4       20.80
# 33             Alencar Santana             1       16.52
# 34            Vanderlei Macris             1       15.00
# 35            Pompeo de Mattos             2       15.00
# 36              Fernando Borja             1       15.00
# 37                   Abou Anni             2       10.40

# %%
df_final.columns
# Out:
# Index(['txNomeParlamentar', 'cpf', 'ideCadastro', 'nuCarteiraParlamentar',
#        'nuLegislatura', 'sgUF', 'sgPartido', 'codLegislatura', 'numSubCota',
#        'txtDescricao', 'numEspecificacaoSubCota', 'txtDescricaoEspecificacao',
#        'txtFornecedor', 'txtCNPJCPF', 'txtNumero', 'indTipoDocumento',
#        'datEmissao', 'vlrDocumento', 'vlrGlosa', 'vlrLiquido', 'numMes',
#        'numAno', 'numParcela', 'txtPassageiro', 'txtTrecho', 'numLote',
#        'numRessarcimento', 'datPagamentoRestituicao', 'vlrRestituicao',
#        'nuDeputadoId', 'ideDocumento', 'urlDocumento', 'cnpj', 'partners',
#        'secondary_activities', 'latitude', 'longitude', 'opening',
#        'main_activity', 'neighborhood', 'share_capital', 'zip_code',
#        'main_activity_code', 'city_code', 'judicial_nature_code',
#        'additional_address_details', 'removed_from_simples_since', 'opened_in',
#        'opted_for_comples_in', 'situation_date', 'special_situation_date',
#        'fax_area_code', 'phone1_area_code', 'phone2_area_code', 'address_type',
#        'responsible_federative_entity', 'hq_or_subsidiary_code', 'address',
#        'situation_reason', 'city', 'legal_entity', 'city_abroad_name',
#        'trade_name', 'number', 'mei', 'simples', 'size',
#        'administrative_person_category', 'name', 'situation',
#        'special_situation', 'phone', 'type', 'state', 'last_updated'],
#       dtype='object')

# %%
(
    df_final[f].query('datEmissao > situation_date')
    .groupby(['txNomeParlamentar', 'txtFornecedor', 'situation'])['ideCadastro'].count()
    .sort_values(ascending=False).to_frame()
)
# Out:
#                                                                                        ideCadastro
# txNomeParlamentar          txtFornecedor                                    situation
# Gleisi Hoffmann            GOL LINHAS AÉREAS INTELIGENTES                   8.00                42
# General Peternelli         PREFEITURA DE SÃO PAULO                          8.00                18
# Carlos Veras               GOL LINHAS AÉREAS INTELIGENTES                   8.00                10
# Lucas Redecker             NET SERVICOS DE COMUNICACAO S/A                  8.00                 8
# Professora Dayane Pimentel NET                                              8.00                 5
# Capitão Augusto            TRANSBRASILIANA - CONCESSIONARIA DE RODOVIA S.A. 8.00                 5
# General Peternelli         HOTELARIA ACCOR BRASIL S/A                       8.00                 4
# Professora Dayane Pimentel Net Serviços de Comunicação S/A                  8.00                 4
# José Airton Félix Cirilo   TIM Celular SA                                   8.00                 4
# Lafayette de Andrada       VOU TAXI BRASIL LTDA                             8.00                 3
# Hermes Parcianello         TRANSBRASILIANA - CONCESSIONARIA DE RODOVIA S.A. 8.00                 3
# Pompeo de Mattos           Point 235                                        8.00                 2
# Paulo Ganime               HOTELARIA ACCOR BRASIL S/A                       8.00                 2
# Luizianne Lins             FM comercio de alimentos e bebidas ltda          8.00                 2
# Geovania de Sá             TIM CELULAR S/A                                  8.00                 2
# Abou Anni                  TRANSBRASILIANA - CONCESSIONARIA DE RODOVIA S.A. 8.00                 2
# Alexandre Padilha          Uber do Brasil Technologia LTDA                  8.00                 2
# Daniel Silveira            Uber do Brasil Technologia LTDA                  8.00                 1
# Darci de Matos             IRMAOS SCHOEPPING LTDA                           8.00                 1
# Túlio Gadêlha              VOU TAXI BRASIL LTDA                             8.00                 1
# Toninho Wandscheer         Auto Posto FRG Ltda                              8.00                 1
# Sóstenes Cavalcante        TAXINOSSO                                        8.00                 1
# Alexandre Padilha          UBER DO BRASIL TECNOLOGIA LTDA.                  8.00                 1
# André de Paula             TAIKAN                                           8.00                 1
# CELSO JACOB                ELCIRO JOSE DUARTE FILHO                         8.00                 1
# Capitão Augusto            Concessionaria Transbrasiliana S/A               8.00                 1
# Carla Zambelli             PREFEITURA DE SÃO PAULO                          8.00                 1
# Carlos Chiodini            GIRAFFAS                                         8.00                 1
# João H. Campos             Net Serviços de Comunicação S.A                  8.00                 1
# José Nunes                 TIM CELULAR S.A.                                 8.00                 1
# Carlos Chiodini            PARANA CAFETERIA LTDA                            8.00                 1
# Jorge Solla                Taxi na Mão Ltda                                 8.00                 1
# Carlos Gomes               Diego Borges dos Santos                          8.00                 1
# Hermes Parcianello         Concessionaria Transbrasiliana S/A               8.00                 1
# Haroldo Cathedral          AZUL LINHAS AÉREAS BRASILEIRAS S.A               8.00                 1
# Coronel Chrisóstomo        GRAN ROMA EIRELI - ME                            8.00                 1
# Coronel Tadeu              TRENDFOODS LP COMERCIO DE ALIMENTOS LTDA         8.00                 1
# Damião Feliciano           NET SERVIÇOS DE COMUNICAÇÃO S/A                  8.00                 1
# Alencar Santana            Uber do Brasil Technologia LTDA                  8.00                 1
# Fábio Ramalho              JORNAL CARTA - WILLIAM HORTA SOBRINHO            8.00                 1
# Fernando Borja             ESTAPAR ESTACIONAMENTO S/C LTDA                  8.00                 1
# Euclydes Pettersen         Gustavo Henrique                                 8.00                 1
# Enéias Reis                AZUL LINHAS AÉREAS BRASILEIRAS S.A               8.00                 1
# Vanderlei Macris           PONTO DE TÁXI SÃO PAULO                          8.00                 1
